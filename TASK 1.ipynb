# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Country-data.csv')

# Display first 5 rows
print("First 5 rows of the dataset:")
print(df.head())
print("\n")

# Display dataset info
print("Dataset information:")
print(df.info())
print("\n")

# Check for missing values
print("Missing values in each column:")
print(df.isnull().sum())
print("\n")

# Display basic statistics
print("Basic statistics of numerical columns:")
print(df.describe())
print("\n")

# Since there don't appear to be missing values, let's just verify data types
# If we needed to clean missing values, we could use:
# df = df.dropna()  # Drop rows with missing values
# or
# df = df.fillna(df.mean())  # Fill missing values with mean

# Save cleaned dataset
df.to_csv('cleaned_country_data.csv', index=False)
# Out:
# First 5 rows of the dataset:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200
#
#
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
# ...
